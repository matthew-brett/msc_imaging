# %% [markdown]
# # On the participants file

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_table('ds009_participants.tsv')
df
# Out:
#    participant_id  age sex  m_SSRTquant  m_NumPumps_Avg  m_TotalAmt_Avg  \
# 0          sub-01   20   F        154.8            5.33           46.00
# 1          sub-02   26   F        259.0            6.17           39.75
# 2          sub-03   22   M        176.1            5.36           42.00
# 3          sub-04   19   M         99.5            5.75           42.50
# 4          sub-05   20   F        125.4            5.72           44.00
# 5          sub-06   21   M        114.8            5.78           43.25
# 6          sub-07   21   M        160.2            5.61           43.00
# 7          sub-09   20   M        196.8            5.61           35.50
# 8          sub-10   19   F        114.6            5.53           37.25
# 9          sub-11   19   F        172.4            5.81           42.00
# 10         sub-12   18   M        143.1            4.78           44.75
# 11         sub-13   18   M        174.0            5.47           39.00
# ...

# %%
df.columns
# Out:
# Index(['participant_id', 'age', 'sex', 'm_SSRTquant', 'm_NumPumps_Avg',
#        'm_TotalAmt_Avg', 'm_NumExplAvg', 'm_logit_k', 'm_AN-SN', 'b_SSRTquant',
#        'b_NumPumps_Avg', 'b_TotalAmt_Avg', 'b_NumExplAvg', 'b_k', 'b_AN-SN',
#        'GABS_TOTAL', 'CARE_ENGAGING-DRUG', 'CARE_ENGAGING-AGGR/ILLEG',
#        'CARE_ENGAGING-SEX', 'CARE_ENGAGING-DRINKING', 'CARE_ENGAGING-SPORTS',
#        'CARE_ENGAGING-TOTAL', 'CARE_NEGCONS-DRUG', 'CARE_NEGCONS-AGGR/ILLEG',
#        'CARE_NEGCONS-SEX', 'CARE_NEGCONS-DRINKING', 'CARE_NEGCONS-SPORTS',
#        'CARE_NEGCONS-TOTAL', 'CARE_POSCONS-DRUG', 'CARE_POSCONS-AGGR/ILLEG',
#        'CARE_POSCONS-SEX', 'CARE_POSCONS-DRINKING', 'CARE_POSCONS-SPORTS',
#        'CARE_POSCONS-TOTAL', 'NEED FOR COG_TOTAL', 'COG REFLECTION_NUM CORR',
#        'COG REFLECTION_CONFIDENCE', 'COG REFLECTION_NUM SEEN',
#        'SENS SEEK_BOREDOM', 'SENS SEEK_DISINHIB', 'SENS SEEK_EXP SEEK',
#        'SENS SEEK_THRILL SEEK', 'SENS SEEK_TOTAL', 'BIS_ATTN', 'BIS_MOTOR',
# ...

# %% [markdown]
# Getting the mean-centered age:

# %%
mc_age = df['age'] - df['age'].mean()
mc_age
# Out:
# 0     -1.083333
# 1      4.916667
# 2      0.916667
# 3     -2.083333
# 4     -1.083333
# 5     -0.083333
# 6     -0.083333
# 7     -1.083333
# 8     -2.083333
# 9     -2.083333
# 10    -3.083333
# 11    -3.083333
# 12    -2.083333
# 13    -1.083333
# 14    -3.083333
# 15     0.916667
# 16     0.916667
# 17     0.916667
# 18    11.916667
# 19     5.916667
# 20    -2.083333
# 21    -2.083333
# 22    -1.083333
# 23     0.916667
# Name: age, dtype: float64

# %% [markdown]
# Writing to a file:

# %%
np.savetxt('mc_age.txt', mc_age, fmt='%.3f')
