# %% [markdown]
# Exploring the task emotional regulation file.

# %% [markdown]
# From Jessica's thesis:
#
# > For the emotion regulation
# > task, the model included events for viewing the attend instructions, viewing
# > the suppress instructions, viewing the three different image types (attend
# > neutral, attend negative, and suppress negative), viewing the rating screen,
# > and a de-meaned parametric regressor weighted by the participant's response.
# > All events began at stimulus onset and lasted either the duration of the
# > stimulus (1 second for instructions, 5 seconds for images) or the
# > participant's RT (viewing the rating screen and the parametric regressor of
# > the participant's rating).  Missed rating trials were included in a nuisance
# > regressor with a duration of 3 seconds. For the image regressors, only
# > images rated as 1-3 (all neutral images) or 5-7 (all negative images) were
# > included. Three participants had less than two instances of at least one of
# > the events and were therefore excluded from the analysis.
#
# See also page 70 of Jessica's thesis where she describes the ER task.  The detail of the procedure starts on page 72.  She says that the participants rated "how negative they felt after either suppressing or attending to the image on a 4-point likert scale from 1 (very slightly or not at all negative) to 4 (extremely negative)".

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_table('ds000009_R2.0.3/sub-03/func/sub-03_task-emotionalregulation_run-02_events.tsv')
df
# Out:
#          onset  duration trial_type image_type image_num response  \
# 0     1.006116         5     attend   negative        66      n/a
# 1     8.009531         3       rate        n/a       n/a      121
# 2    13.004863         5     attend    neutral        99      n/a
# 3    19.012506         3       rate        n/a       n/a       98
# 4    29.003229         5     attend   negative        72      n/a
# 5    37.002353         3       rate        n/a       n/a      103
# 6    43.009871         5   suppress   negative         7      n/a
# 7    49.001151         3       rate        n/a       n/a      121
# 8    53.017403         5   suppress   negative        17      n/a
# 9    60.004128         3       rate        n/a       n/a      121
# 10   65.016025         5   suppress   negative         4      n/a
# 11   71.007043         3       rate        n/a       n/a      103
# 12   77.014828         5   suppress   negative        20      n/a
# 13   84.001665         3       rate        n/a       n/a       98
# 14   89.013598         5     attend    neutral        89      n/a
# 15   95.004692         3       rate        n/a       n/a       98
# 16   99.004218         5     attend   negative        63      n/a
# 17  105.011895         3       rate        n/a       n/a      121
# 18  111.002954         5     attend   negative        76      n/a
# 19  119.002158         3       rate        n/a       n/a      121
# 20  127.001335         5   suppress   negative         8      n/a
# 21  134.004710         3       rate        n/a       n/a      121
# 22  141.008143         5     attend    neutral        96      n/a
# 23  147.015849         3       rate        n/a       n/a       98
# 24  151.015494         5     attend   negative        80      n/a
# 25  159.014686         3       rate        n/a       n/a      121
# 26  170.017653         5     attend    neutral        98      n/a
# 27  177.004516         3       rate        n/a       n/a       98
# 28  183.012159         5     attend   negative        78      n/a
# 29  190.015605         3       rate        n/a       n/a       98
# 30  194.015103         5     attend    neutral        94      n/a
# 31  201.002047         3       rate        n/a       n/a        0
# 32  205.001597         5     attend    neutral        86      n/a
# 33  212.005135         3       rate        n/a       n/a        0
# 34  217.016990         5   suppress   negative         9      n/a
# 35  223.007941         3       rate        n/a       n/a      121
# 36  233.015294         5     attend    neutral        85      n/a
# 37  241.014504         3       rate        n/a       n/a       98
# 38  248.001417         5     attend   negative        73      n/a
# 39  254.008987         3       rate        n/a       n/a      103
# 40  259.004344         5   suppress   negative        13      n/a
# 41  266.007754         3       rate        n/a       n/a      121
# 42  272.015428         5     attend    neutral        91      n/a
# 43  280.014689         3       rate        n/a       n/a       98
# 44  285.009988         5     attend    neutral        81      n/a
# 45  292.013438         3       rate        n/a       n/a        0
# 46  297.008795         5   suppress   negative         6      n/a
# 47  305.007883         3       rate        n/a       n/a        0
# 48  309.007489         5     attend   negative        67      n/a
# 49  316.010896         3       rate        n/a       n/a      121
# 50  320.010501         5   suppress   negative        12      n/a
# 51  326.001588         3       rate        n/a       n/a       98
# 52  339.012690         5   suppress   negative        18      n/a
# 53  347.011797         3       rate        n/a       n/a       98
# 54  353.002985         5     attend   negative        61      n/a
# 55  362.014446         3       rate        n/a       n/a      121
# 56  367.009741         5     attend   negative        79      n/a
# 57  375.008957         3       rate        n/a       n/a        0
# 58  380.004294         5     attend    neutral        82      n/a
# 59  386.012042         3       rate        n/a       n/a       98
#
#         reaction_time  trial_num  onset_orig  duration_orig trial_type_orig  \
# 0                 n/a          1      1.0061              5         att_neg
# 1   0.444869896000455          1      8.0095              3      rating_par
# 2                 n/a          2     13.0049              5        att_neut
# 3   0.832420872999137          2     19.0125              3      rating_par
# 4                 n/a          3     29.0032              5         att_neg
# 5   0.647769164001147          3     37.0024              3      rating_par
# 6                 n/a          4     43.0099              5       suppr_neg
# 7   0.633277414999611          4     49.0012              3      rating_par
# 8                 n/a          5     53.0174              5       suppr_neg
# 9   0.328617319999466          5     60.0041              3      rating_par
# 10                n/a          6     65.0160              5       suppr_neg
# 11  0.580525804998615          6     71.0070              3      rating_par
# 12                n/a          7     77.0148              5       suppr_neg
# 13   2.41682010900149          7     84.0017              3      rating_par
# 14                n/a          8     89.0136              5        att_neut
# 15  0.846524471000521          8     95.0047              3      rating_par
# 16                n/a          9     99.0042              5         att_neg
# 17  0.433373163999931          9    105.0119              3      rating_par
# 18                n/a         10    111.0030              5         att_neg
# 19  0.912241041000016         10    119.0022              3      rating_par
# 20                n/a         11    127.0013              5       suppr_neg
# 21  0.368491273000473         11    134.0047              3      rating_par
# 22                n/a         12    141.0081              5        att_neut
# 23  0.507827153998733         12    147.0158              3      rating_par
# 24                n/a         13    151.0155              5         att_neg
# 25  0.532986761998473         13    159.0147              3      rating_par
# 26                n/a         14    170.0177              5        att_neut
# 27   2.12862124299863         14    177.0045              3      rating_par
# 28                n/a         15    183.0122              5         att_neg
# 29  0.957595021000088         15    190.0156              3      rating_par
# 30                n/a         16    194.0151              5        att_neut
# 31                  0         16    201.0020              3     junk_rating
# 32                n/a         17    205.0016              5        att_neut
# 33                  0         17    212.0051              3     junk_rating
# 34                n/a         18    217.0170              5       suppr_neg
# 35    0.9466490850009         18    223.0079              3      rating_par
# 36                n/a         19    233.0153              5        att_neut
# 37   1.65966503699929         19    241.0145              3      rating_par
# 38                n/a         20    248.0014              5         att_neg
# 39   1.13733544599927         20    254.0090              3      rating_par
# 40                n/a         21    259.0043              5       suppr_neg
# 41   0.93994757099972         21    266.0078              3      rating_par
# 42                n/a         22    272.0154              5        att_neut
# 43    1.8596909730004         22    280.0147              3      rating_par
# 44                n/a         23    285.0100              5        att_neut
# 45                  0         23    292.0134              3     junk_rating
# 46                n/a         24    297.0088              5       suppr_neg
# 47                  0         24    305.0079              3     junk_rating
# 48                n/a         25    309.0075              5         att_neg
# 49  0.849447254000552         25    316.0109              3      rating_par
# 50                n/a         26    320.0105              5       suppr_neg
# 51   1.60920125600023         26    326.0016              3      rating_par
# 52                n/a         27    339.0127              5       suppr_neg
# 53    2.4712431959997         27    347.0118              3      rating_par
# 54                n/a         28    353.0030              5         att_neg
# 55  0.502263876998768         28    362.0144              3      rating_par
# 56                n/a         29    367.0097              5         att_neg
# 57                  0         29    375.0090              3     junk_rating
# 58                n/a         30    380.0043              5        att_neut
# 59   1.06460434600012         30    386.0120              3      rating_par
#
#    rating_par_orig
# 0              n/a
# 1             0.32
# 2              n/a
# 3            -0.68
# 4              n/a
# 5             1.32
# 6              n/a
# 7             0.32
# 8              n/a
# 9             0.32
# 10             n/a
# 11            1.32
# 12             n/a
# 13           -0.68
# 14             n/a
# 15           -0.68
# 16             n/a
# 17            0.32
# 18             n/a
# 19            0.32
# 20             n/a
# 21            0.32
# 22             n/a
# 23           -0.68
# 24             n/a
# 25            0.32
# 26             n/a
# 27           -0.68
# 28             n/a
# 29           -0.68
# 30             n/a
# 31             n/a
# 32             n/a
# 33             n/a
# 34             n/a
# 35            0.32
# 36             n/a
# 37           -0.68
# 38             n/a
# 39            1.32
# 40             n/a
# 41            0.32
# 42             n/a
# 43           -0.68
# 44             n/a
# 45             n/a
# 46             n/a
# 47             n/a
# 48             n/a
# 49            0.32
# 50             n/a
# 51           -0.68
# 52             n/a
# 53           -0.68
# 54             n/a
# 55            0.32
# 56             n/a
# 57             n/a
# 58             n/a
# 59           -0.68

# %% [markdown]
# In the old onsets (from a previous version of the ds009 dataset), `cond001` is attend negative:

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond001.txt
# Out:
# 1.0061	5	1
# 29.0032	5	1
# 99.0042	5	1
# 111.0030	5	1
# 151.0155	5	1
# 183.0122	5	1
# 248.0014	5	1
# 309.0075	5	1
# 353.0030	5	1
# 367.0097	5	1

# %% [markdown]
# `cond002` is attend neutral:

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond002.txt
# Out:
# 13.0049	5	1
# 89.0136	5	1
# 141.0081	5	1
# 170.0177	5	1
# 194.0151	5	1
# 205.0016	5	1
# 233.0153	5	1
# 272.0154	5	1
# 285.0100	5	1
# 380.0043	5	1

# %% [markdown]
# `cond003` is the rate event (without parametric scaling).  The durations are all 3 (they do not use the reaction time).  In fact this is so for most but not all subjects.  Subjects 13 through 17 do use the RT.

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond003.txt
# Out:
# 8.0095	3	1
# 19.0125	3	1
# 37.0024	3	1
# 49.0012	3	1
# 60.0041	3	1
# 71.0070	3	1
# 84.0017	3	1
# 95.0047	3	1
# 105.0119	3	1
# 119.0022	3	1
# 134.0047	3	1
# 147.0158	3	1
# 159.0147	3	1
# 177.0045	3	1
# 190.0156	3	1
# 223.0079	3	1
# 241.0145	3	1
# 254.0090	3	1
# 266.0078	3	1
# 280.0147	3	1
# 316.0109	3	1
# 326.0016	3	1
# 347.0118	3	1
# 362.0144	3	1
# 386.0120	3	1

# %% [markdown]
# `cond004` is the rate regressor (with parametric scaling of amplitude).

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond004.txt
# Out:
# 8.0095	3	0.3200
# 19.0125	3	-0.6800
# 37.0024	3	1.3200
# 49.0012	3	0.3200
# 60.0041	3	0.3200
# 71.0070	3	1.3200
# 84.0017	3	-0.6800
# 95.0047	3	-0.6800
# 105.0119	3	0.3200
# 119.0022	3	0.3200
# 134.0047	3	0.3200
# 147.0158	3	-0.6800
# 159.0147	3	0.3200
# 177.0045	3	-0.6800
# 190.0156	3	-0.6800
# 223.0079	3	0.3200
# 241.0145	3	-0.6800
# 254.0090	3	1.3200
# 266.0078	3	0.3200
# 280.0147	3	-0.6800
# 316.0109	3	0.3200
# 326.0016	3	-0.6800
# 347.0118	3	-0.6800
# 362.0144	3	0.3200
# 386.0120	3	-0.6800

# %% [markdown]
# `cond05` is suppress negative.

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond005.txt
# Out:
# 43.0099	5	1
# 53.0174	5	1
# 65.0160	5	1
# 77.0148	5	1
# 127.0013	5	1
# 217.0170	5	1
# 259.0043	5	1
# 297.0088	5	1
# 320.0105	5	1
# 339.0127	5	1

# %% [markdown]
# `cond006` may be the missed ratings, with `trial_type_orig` field value of `junk_rating`, and rating 0.

# %%
cat old_onsets/sub003/model/model001/onsets/task003_run002/cond006.txt
# Out:
# 201.0020	3	1
# 212.0051	3	1
# 292.0134	3	1
# 305.0079	3	1
# 375.0090	3	1

# %% [markdown]
# Differences between .tsv file, old onsets and Jessica's description:
#
# * no "instructions" events in .tsv file or in old onsets;
# * rating events have standard 3 second duration, not the reaction time;

# %% [markdown]
# In the next cell, I confirm that there are no other event types in the current `.tsv` file.  I'm using `trial_type_orig` - `trial_type` has fewer options.

# %%
# All trial types noted in "trial_type_orig"
set(df['trial_type_orig'])
# Out:
# {'att_neg', 'att_neut', 'junk_rating', 'rating_par', 'suppr_neg'}

# %% [markdown]
# Let's collect the trial types and responses from the dataframes of all the .tsv files.  We also look at the association of the `response` variable value with the `rating_par_orig`.

# %%
from glob import glob
from os.path import join as pjoin

all_trial_types = set()
all_responses = set()
all_response_pairs = set()
par_vals = []

for tsv_path in glob(pjoin('ds000009_R2.0.3',
                           'sub-*',
                           'func',
                           'sub*emotionalregulation*.tsv')):
    this_df = pd.read_table(tsv_path)
    # Add any unknown trial types from this tsv
    all_trial_types = all_trial_types.union(this_df['trial_type_orig'])
    # Now analyze the rating trials
    is_rate = this_df['trial_type'] == 'rate'
    rate_trials = this_df[is_rate]
    responses = rate_trials['response']
    # Get old parametric regressor, recoded from 1 - 4.
    old_par = pd.to_numeric(this_df['rating_par_orig'], 'coerce')
    old_par = old_par - np.nanmin(old_par) + 1
    all_responses = all_responses.union(responses)
    response_pairs = zip(responses, old_par[is_rate])
    all_response_pairs = all_response_pairs.union(response_pairs)
    # Look at response for different trial types
    last_valence = this_df['image_type'].copy()
    last_valence[this_df['trial_type'] == 'suppress'] = 'suppress'
    last_valence[1:] = last_valence[:-1]
    # Store for later analysis (see below)
    par_vals.append(pd.concat([old_par, last_valence], axis=1).dropna())

# %% [markdown]
# There are no trial types for the instructions for any subject:

# %%
all_trial_types
# Out:
# {'att_neg', 'att_neut', 'junk_rating', 'rating_par', 'suppr_neg'}

# %% [markdown]
# There are 4 responses occurring across all the .tsv files (and 0):

# %%
all_responses
# Out:
# {'0', '103', '114', '121', '98'}

# %% [markdown]
# The pairings of the recoded `rating_par_orig` and response numbers are:

# %%
all_response_pairs
# Out:
# {('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('0', nan),
#  ('103', 3.0),
#  ('114', 4.0),
#  ('121', 2.0),
#  ('98', 1.0)}

# %% [markdown]
# Notice that the button codes are not in order - although 98 maps to 1, 103 maps to 3 and 121 maps to 2.

# %% [markdown]
# It looks as if 4 is the most negative, 1 is the least negative:

# %%
all_par_vals = pd.concat(par_vals, axis=0, ignore_index=True)
all_par_vals.groupby('image_type').mean()
# Out:
#             rating_par_orig
# image_type
# negative           2.469345
# neutral            1.042373
# suppress           1.687234

# %% [markdown]
# Now let's try recreating the old condition files:

# %%
ER_RESPONSE_MAP = {'114': 4, '103': 3, '121': 2, '98': 1, '0': 0,
                   'n/a': np.nan}

def er_preprocessor(df):
    """ Process dataframe for ER trial types """
    onset, duration, trial_type, image_type, response, rt = [
        df[name].copy() for name in
        ['onset', 'duration', 'trial_type', 'image_type',
         'response', 'reaction_time']]
    # Recode the response values using the map above.
    response = response.map(ER_RESPONSE_MAP)
    tt = trial_type.copy()  # A pandas series
    tt[(trial_type == 'attend') & (image_type == 'negative')] = 'attendneg'
    tt[(trial_type == 'attend') & (image_type == 'neutral')] = 'attendneu'
    tt[(trial_type == 'suppress') & (image_type == 'negative')] = 'suppressneg'
    assert not any((trial_type == 'suppress') & (image_type == 'neutral'))
    tt[(trial_type == "rate") & (response == 0)] = 'ratemiss'
    tt[(trial_type == "rate") & (response != 0)] = 'rate'
    # Use RTs as durations for rate
    good_rates = tt == 'rate'
    duration[good_rates] = pd.to_numeric(rt[good_rates])
    # Make main set of events (excluding parametric regressor)
    amplitude = pd.Series(np.ones(len(df)), name='amplitude')
    main_trials = pd.concat([tt, onset, duration, amplitude], axis=1)
    # Add parametric trial type
    good_onsets = onset[good_rates]
    good_durations = duration[good_rates]
    good_responses = response[good_rates]
    amp_extra = good_responses - np.mean(good_responses)
    amp_extra.name = 'amplitude'
    tt_extra = tt[good_rates]
    tt_extra[:] = 'ratepar'
    # Put the new trials at the end
    extra = pd.concat([tt_extra, good_onsets, good_durations, amp_extra], axis=1)
    return pd.concat([main_trials, extra], axis=0, ignore_index=True)

# %%
events = er_preprocessor(df)
events
# Out:
#      trial_type       onset  duration  amplitude
# 0     attendneg    1.006116  5.000000       1.00
# 1          rate    8.009531  0.444870       1.00
# 2     attendneu   13.004863  5.000000       1.00
# 3          rate   19.012506  0.832421       1.00
# 4     attendneg   29.003229  5.000000       1.00
# 5          rate   37.002353  0.647769       1.00
# 6   suppressneg   43.009871  5.000000       1.00
# 7          rate   49.001151  0.633277       1.00
# 8   suppressneg   53.017403  5.000000       1.00
# 9          rate   60.004128  0.328617       1.00
# 10  suppressneg   65.016025  5.000000       1.00
# 11         rate   71.007043  0.580526       1.00
# 12  suppressneg   77.014828  5.000000       1.00
# 13         rate   84.001665  2.416820       1.00
# 14    attendneu   89.013598  5.000000       1.00
# 15         rate   95.004692  0.846524       1.00
# 16    attendneg   99.004218  5.000000       1.00
# 17         rate  105.011895  0.433373       1.00
# 18    attendneg  111.002954  5.000000       1.00
# 19         rate  119.002158  0.912241       1.00
# 20  suppressneg  127.001335  5.000000       1.00
# 21         rate  134.004710  0.368491       1.00
# 22    attendneu  141.008143  5.000000       1.00
# 23         rate  147.015849  0.507827       1.00
# 24    attendneg  151.015494  5.000000       1.00
# 25         rate  159.014686  0.532987       1.00
# 26    attendneu  170.017653  5.000000       1.00
# 27         rate  177.004516  2.128621       1.00
# 28    attendneg  183.012159  5.000000       1.00
# 29         rate  190.015605  0.957595       1.00
# ..          ...         ...       ...        ...
# 55         rate  362.014446  0.502264       1.00
# 56    attendneg  367.009741  5.000000       1.00
# 57     ratemiss  375.008957  3.000000       1.00
# 58    attendneu  380.004294  5.000000       1.00
# 59         rate  386.012042  1.064604       1.00
# 60      ratepar    8.009531  0.444870       0.32
# 61      ratepar   19.012506  0.832421      -0.68
# 62      ratepar   37.002353  0.647769       1.32
# 63      ratepar   49.001151  0.633277       0.32
# 64      ratepar   60.004128  0.328617       0.32
# 65      ratepar   71.007043  0.580526       1.32
# 66      ratepar   84.001665  2.416820      -0.68
# 67      ratepar   95.004692  0.846524      -0.68
# 68      ratepar  105.011895  0.433373       0.32
# 69      ratepar  119.002158  0.912241       0.32
# 70      ratepar  134.004710  0.368491       0.32
# 71      ratepar  147.015849  0.507827      -0.68
# 72      ratepar  159.014686  0.532987       0.32
# 73      ratepar  177.004516  2.128621      -0.68
# 74      ratepar  190.015605  0.957595      -0.68
# 75      ratepar  223.007941  0.946649       0.32
# 76      ratepar  241.014504  1.659665      -0.68
# 77      ratepar  254.008987  1.137335       1.32
# 78      ratepar  266.007754  0.939948       0.32
# 79      ratepar  280.014689  1.859691      -0.68
# 80      ratepar  316.010896  0.849447       0.32
# 81      ratepar  326.001588  1.609201      -0.68
# 82      ratepar  347.011797  2.471243      -0.68
# 83      ratepar  362.014446  0.502264       0.32
# 84      ratepar  386.012042  1.064604      -0.68
#
# [85 rows x 4 columns]

# %% [markdown]
# Compare the `rating_par_orig` to the recalculated rating.

# %%
good_rates = (df['trial_type'] == "rate") & (df['response'] != '0')
orig = df['rating_par_orig'][good_rates].astype(float)
orig
# Out:
# 1     0.32
# 3    -0.68
# 5     1.32
# 7     0.32
# 9     0.32
# 11    1.32
# 13   -0.68
# 15   -0.68
# 17    0.32
# 19    0.32
# 21    0.32
# 23   -0.68
# 25    0.32
# 27   -0.68
# 29   -0.68
# 35    0.32
# 37   -0.68
# 39    1.32
# 41    0.32
# 43   -0.68
# 49    0.32
# 51   -0.68
# 53   -0.68
# 55    0.32
# 59   -0.68
# Name: rating_par_orig, dtype: float64

# %%
new_par = events[events['trial_type'] == 'ratepar']['amplitude']
new_par
# Out:
# 60    0.32
# 61   -0.68
# 62    1.32
# 63    0.32
# 64    0.32
# 65    1.32
# 66   -0.68
# 67   -0.68
# 68    0.32
# 69    0.32
# 70    0.32
# 71   -0.68
# 72    0.32
# 73   -0.68
# 74   -0.68
# 75    0.32
# 76   -0.68
# 77    1.32
# 78    0.32
# 79   -0.68
# 80    0.32
# 81   -0.68
# 82   -0.68
# 83    0.32
# 84   -0.68
# Name: amplitude, dtype: float64

# %% [markdown]
# The new values are (almost) the same as the old.

# %%
np.allclose(orig, new_par)
# Out:
# True
